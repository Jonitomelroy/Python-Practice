# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
x=[1,32,4,3,2,4,53,54,45,100,45,4,345,34,5]
sns.boxplot(x)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
x=[1,32,4,3,2,4,53,54,45,100,45,4,345,34,5]
sns.histplot(x)
plt.show()

# %%
sns.scatterplot(x)
# Out:
# <Axes: >
