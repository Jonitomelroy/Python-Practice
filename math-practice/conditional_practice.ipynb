# %%
a=int(input("A"))
b=int(input("b"))
c=int(input("c"))
if a>b and b>c:
  print(a)
elif b>a and a>c:
  print(b)
else:
  print(c)
# Out:
# A1
# b4
# c7
# 7

# %%
largest=max(a,b,c)
print(largest)
# Out:
# 7

# %%
n=int(input("n="))
sum=0
for i in range(n+1):
  sum+=i
print(sum)
# Out:
# n=5
# 15

# %%
k=[1,2,3,4,5,6,7,8]
sum=0
for i in k:
  if i%2==0:
    sum+=i
print(sum)
# Out:
# 20

# %%
k=[1,2,3,4,5,6,7,8]
count=0
for i in k:
  if i%2==0:
    count+=1
print(count)
# Out:
# 4
