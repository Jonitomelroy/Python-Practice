# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df =pd.read_csv("/content/Falcon .csv")
df.head()
df.sample(10)


sns.histplot(y="Academic Year" , x="Jersey size" , data=df)
plt.show()

# %%
sns.barplot(x="Academic Year" , y="Jersey size" , data=df)
# Out:
# <Axes: xlabel='Academic Year', ylabel='Jersey size'>

# %%
df.sample(10)
# Out:
#                           Timestamp                        Name  \
# 13  2025/08/01 12:33:38 pm GMT+5:30                       Ashok
# 21   2025/08/02 6:58:35 pm GMT+5:30               Aditya Gurung
# 22  2025/08/02 11:36:07 pm GMT+5:30      Jonito Melroy D'silva
# 31  2025/08/08 11:04:16 am GMT+5:30  Latisha Rajendra Lotlikar
# 1    2025/07/31 3:27:35 pm GMT+5:30                   Delin vaz
# 47   2025/08/09 8:23:52 pm GMT+5:30    Vaibhav Sandesh kholkar
# 0    2025/07/31 3:24:09 pm GMT+5:30                  Zubair MK
# 37   2025/08/08 6:18:56 pm GMT+5:30      Akanksha arun kumbhar
# 51   2025/08/13 4:43:58 pm GMT+5:30                Siddhi Manve
# 30  2025/08/07 12:04:30 pm GMT+5:30               Sachin lamani
#
#        Academic Year                         Stream  \
# 13  SY (Second Year)           Business Management
# 21   TY (Third Year)           Business management
# 22   FY (First Year)               Bsc data science
# 31   FY (First Year)                B.com (General)
# ...

# %%
pen=sns.load_dataset('penguins')
sns.barplot(x="island" , y="body_mass_g" , data=pen)
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.histplot(x="island" , y="body_mass_g" , kde=True ,hue="sex", data=pen)
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.lineplot(x="island" , y="body_mass_g" , data=pen)
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.boxplot(x="island" , y="body_mass_g" , data=pen)
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
plt.scatter(x="island" , y="body_mass_g",data=pen)

# %%
sns.countplot(x="island" , data=pen)
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
sns.histplot(x="bill_length_mm" ,bins=100, kde=True, data=pen)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.scatterplot(x="bill_length_mm" , y="bill_depth_mm" , data=pen)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.catplot(x="island" , y="body_mass_g" , data=pen)

# %%
sns.pairplot(pen,hue="sex")

# %%
pen.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
