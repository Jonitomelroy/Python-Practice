# %%
import pandas as pd
df=pd.read_excel('/content/isa22222222.xlsx')
df.head(10)
# Out:
#        Name  Age  Gender           City         Occupation    Salary  \
# 0      John   30    Male       New York  Software Engineer   $90,000
# 1     Sarah   25  Female    Los Angeles           Designer   $75,000
# 2   Michael   35    Male        Chicago  Marketing Manager   $85,000
# 3      Emma   28  Female          Miami       Data Analyst   $70,000
# 4    Olivia   40  Female         Boston         HR Manager   $95,000
# 5      Liam   32    Male  San Francisco    Product Manager  $110,000
# 6      Noah   27    Male        Seattle   Graphic Designer   $65,000
# 7       Ava   22  Female         Austin   Marketing Intern   $45,000
# 8     Lucas   33    Male         Denver      Web Developer   $80,000
# 9  Isabella   29  Female       Portland   Product Designer   $78,000
#
#   Start Date
# 0 2020-01-15
# 1 2019-05-22
# 2 2017-08-11
# 3 2021-02-18
# 4 2016-11-09
# 5 2018-03-01
# 6 2020-06-10
# 7 2023-01-25
# 8 2019-09-30
# 9 2022-07-16

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_excel('/content/isa22222222.xlsx')
sns.barplot(x='City',y='Age',hue='Gender',data=df)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_excel('/content/isa22222222.xlsx')
sns.barplot(x='Start Date',y='Age',hue='Gender',data=df)
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels
plt.tight_layout() # Adjust layout to prevent labels from being cut off

plt.show()
